# %% [markdown]
# # DFU-ImageGuard — Load Latest Reproducibility Artifacts
#
# Mount Drive with the same verified storage logic, locate the latest completed run, load the trusted PKL without retraining, and display saved metrics and paths.

# %%
import sys, subprocess, importlib, shutil
from pathlib import Path
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--disable-pip-version-check", "pandas>=2.2", "numpy>=1.26", "matplotlib>=3.9", "Pillow>=10.4"])
REPO = Path("/content/DFU-ImageGuard")
if (REPO / ".git").exists():
    subprocess.run(["git", "-C", str(REPO), "fetch", "origin", "main"], check=True)
    subprocess.run(["git", "-C", str(REPO), "reset", "--hard", "origin/main"], check=True)
else:
    if REPO.exists():
        shutil.rmtree(REPO)
    subprocess.check_call(["git", "clone", "https://github.com/AzizulHakim00/DFU-ImageGuard.git", str(REPO)])
for module_name in list(sys.modules):
    if module_name == "src" or module_name.startswith("src."):
        del sys.modules[module_name]
importlib.invalidate_caches()
if str(REPO) not in sys.path:
    sys.path.insert(0, str(REPO))
from src.dfu_imageguard_pipeline import load_latest_artifacts
ARTIFACTS = load_latest_artifacts()
