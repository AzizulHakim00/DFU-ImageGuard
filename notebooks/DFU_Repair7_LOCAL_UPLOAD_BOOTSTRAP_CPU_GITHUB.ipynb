# %% [markdown]
# # DFU Repair-7 — Local Upload Bootstrap + CPU Repair
# Run the cell. Colab will ask you to upload **one local file**: `DFU_GOOD38_RECOVERY_EVIDENCE.zip`. The script reconstructs the locked assignments from the verified V4 evidence, restores GOOD38 without training, and then permits training only for the original BAD7.

# %%
import urllib.request
URL = 'https://raw.githubusercontent.com/AzizulHakim00/DFU-ImageGuard/d24b690d1b7a12eb6e0f1c01edbb5ac59dbd5487/notebooks/repair7_local_upload/dfu_local_upload_bootstrap.py'
code = urllib.request.urlopen(URL, timeout=120).read().decode('utf-8')
compile(code, 'dfu_local_upload_bootstrap.py', 'exec')
print('Pinned local-upload bootstrap: PASS')
print('Next action: choose DFU_GOOD38_RECOVERY_EVIDENCE.zip from your computer')
exec(compile(code, 'dfu_local_upload_bootstrap.py', 'exec'), globals())
