# %%
# DFU Repair45 Locked-Recovery V2 — one-cell commit-pinned loader
import urllib.request

VERSION = "DFU_REPAIR45_LOCKED_RECOVERY_LOADER_V2_20260810"
SOURCE_COMMIT = "a94316d14781c9bd4fe371dc2e36583a5a65ee6a"
SOURCE_URL = (
    "https://raw.githubusercontent.com/AzizulHakim00/DFU-ImageGuard/"
    + SOURCE_COMMIT
    + "/scripts/dfu_repair45_locked_recovery_v2.py"
)

print(VERSION)
print("Loader mode: immutable commit-pinned plain .py; no nested notebook parsing")
print("Stage 1: recover/verify locked split; Stage 2: reconcile 45; Stage 3: GPU only for non-GOOD")

raw = urllib.request.urlopen(SOURCE_URL, timeout=120).read()
code = raw.decode("utf-8")
compile(code, "dfu_repair45_locked_recovery_v2.py", "exec")
print("Pinned Locked-Recovery V2 source compile: PASS")
exec(compile(code, "dfu_repair45_locked_recovery_v2.py", "exec"), globals())
