# %% [markdown]
# # Future Ablation Study — Disabled by Default
#
# Ablation requires separately training modified model variants with the same locked folds. It cannot be inferred from the completed primary checkpoints.

# %%
import sys, subprocess
from pathlib import Path
REPO = Path("/content/DFU-ImageGuard")
if (REPO / ".git").exists():
    subprocess.run(["git", "-C", str(REPO), "pull", "--rebase", "origin", "main"], check=False)
else:
    subprocess.check_call(["git", "clone", "https://github.com/AzizulHakim00/DFU-ImageGuard.git", str(REPO)])
sys.path.insert(0, str(REPO))
from src.dfu_imageguard_pipeline import future_notebook_guard
RUN_ABLATION = False
future_notebook_guard("ablation")
if RUN_ABLATION:
    raise NotImplementedError("Define preregistered variants and training budget before enabling ablation fits.")
